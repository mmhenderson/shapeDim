# %%
import numpy as np
import os, sys
import pandas as pd
import scipy.stats
import scipy.io as spio


# root directory is 2 dirs up from this file
# path = os.path.realpath(__file__).split('/')
# root = '/'+os.path.join(*path[0:-3])
root = '/usr/local/serenceslab/maggie/shapeDim/'
sys.path.append(os.path.join(root, 'Analysis'))

import matplotlib.pyplot as plt

from code_utils import data_utils, file_utils

# %%
import PIL

folder = os.path.join(root, 'DataPreproc','S07')
files = os.listdir(folder)
files = [f for f in files if '.tif' in f]

for ii in range(6):

    # print(files[ii])
    im = PIL.Image.open(os.path.join(folder, files[ii]))
    plt.figure(figsize=(12,8))
    plt.imshow(im);
    plt.axis('off')
    plt.title(files[ii])
