# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import pandas as pd

root = '/usr/local/serenceslab/maggie/shapeDim/'

sys.path.append(os.path.join(root, 'Analysis'))
from code_utils import file_utils, grid_utils

# %%
grid_utils.get_quadrant(np.array([[4,1]]))
# Out:
# array([4])

# %%
all_grid_points = grid_utils.get_full_grid()
n_pts_all_grid = all_grid_points.shape[0]

# %%
grid_pts = grid_utils.get_main_grid()

# %%
grid_utils.get_categ(grid_pts, 1)
# Out:
# array([2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 2, 1, 1])

# %%
plt.figure()
dist = grid_utils.get_dist_from_center(grid_pts).round(3)
for dd in np.unique(dist):
    inds = dist==dd
    plt.plot(grid_pts[inds,0], grid_pts[inds,1], '.')

# %%
for tt in [1,2,3]:
    plt.figure()
    # pts = np.random.normal(2.5, 1, [20,2])
    # categ = get_categ(pts, tt)
    categ = grid_utils.get_categ(grid_pts, tt)
    for cc in [1,2]:
        inds = categ==cc
        plt.plot(grid_pts[inds,0], grid_pts[inds,1], '.')
        # plt.plot(pts[inds,0], pts[inds,1], '.')

# %%
for tt in [1,2,3]:
    plt.figure()
    # pts = np.random.normal(2.5, 1, [20,2])
    # categ = get_categ(pts, tt)
    dist = grid_utils.get_dist_from_bound(grid_pts, tt).round(3)
    for dd in np.unique(dist):
        inds = dist==dd
        plt.plot(grid_pts[inds,0], grid_pts[inds,1], '.')
        # plt.plot(pts[inds,0], pts[inds,1], '.')
