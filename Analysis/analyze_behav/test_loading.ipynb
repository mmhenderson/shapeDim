# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import pandas as pd
import scipy.stats

root = '/usr/local/serenceslab/maggie/shapeDim/'

sys.path.append(os.path.join(root, 'Analysis'))
from code_utils import file_utils

# %%
from code_utils import data_utils
make_time_resolved = False

for ss in np.arange(1,8):
    main_data, main_data_by_tr, main_labels, roi_names = data_utils.load_main_task_data(ss, make_time_resolved)
    rep_data, rep_data_by_tr, rep_labels, roi_names = data_utils.load_repeat_task_data(ss, make_time_resolved)
# Out:
# loading from /usr/local/serenceslab/maggie/shapeDim/Samples/SampleFile_S01.mat
# loading from /usr/local/serenceslab/maggie/shapeDim/Samples/TimingFile_S01.mat
# loading from /usr/local/serenceslab/maggie/shapeDim/DataBehavior/S01/S01_maintask_preproc_all.csv
# processing area V1, 1866 voxels
# processing area V2, 1236 voxels
# processing area V3, 1109 voxels
# processing area V3AB, 1013 voxels
# processing area hV4, 277 voxels
# processing area IPS0, 476 voxels
# processing area IPS1, 182 voxels
# processing area IPS2, 85 voxels
# processing area IPS3, 271 voxels
# processing area LO1, 369 voxels
# processing area LO2, 152 voxels
# loading from /usr/local/serenceslab/maggie/shapeDim/Samples/SampleFile_S01.mat
# loading from /usr/local/serenceslab/maggie/shapeDim/Samples/TimingFile_S01.mat
# loading from /usr/local/serenceslab/maggie/shapeDim/DataBehavior/S01/S01_reptask_preproc_all.csv
# processing area V1, 1866 voxels
# processing area V2, 1236 voxels
# ...
